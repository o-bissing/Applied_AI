# %%
import pandas as pd

# %%
dt_acc = 0.64375
dt_bal_acc = 0.36976899334322627
svm_acc = 0.44375
svm_bal_acc = 0.19153697487539414
nn_acc = 0.621875
nn_bal_acc = 0.29932551968155685

# %%
index = ['dt', 'svm', 'nn']
columns = ['accuracy', 'balanced_accuracy']
data = [[0.64375, 0.36976899334322627], [0.44375, 0.19153697487539414], [0.621875, 0.29932551968155685]]

# %%
df = pd.DataFrame(data, index, columns)
df
# Out:
#      accuracy  balanced_accuracy
# dt   0.643750           0.369769
# svm  0.443750           0.191537
# nn   0.621875           0.299326

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
# Bar plot shows, that decision trees show the best both accuracy and balanced_accuracy
