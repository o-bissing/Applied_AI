# %% [markdown]
# <a href="https://colab.research.google.com/github/o-bissing/Applied_AI/blob/main/Image_classification_models_comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
index = ['VGG19', 'EfficientNet', 'MobileNet', 'DenseNet', 'ResNet50']

# %%
# Airliner:
columns = ['Airliner']

VGG19 = 0.7563691139221191
EfficientNetB0 = 0.3092358708381653
MobileNet = 0.5665768980979919
DenseNet121 = 0.5370401740074158
ResNet50 = 0.021923772990703583

data = [VGG19, EfficientNetB0, MobileNet, DenseNet121, ResNet50]

df = pd.DataFrame(data, index, columns)
df.plot.bar()
# Out:
# <Axes: >

# %%
# Cannon:
columns = ['Cannon']

VGG19 = 0.820897102355957
EfficientNetB0 = 0.9093706607818604
MobileNet = 0.9754392504692078
DenseNet121 = 0.9499104619026184
ResNet50 = 0.9764938950538635

data = [VGG19, EfficientNetB0, MobileNet, DenseNet121, ResNet50]

df = pd.DataFrame(data, index, columns)
df.plot.bar()
# Out:
# <Axes: >

# %%
# Carrot: there obviously (and surprisingly) no such category in this model because no model had guessed it

# %%
# Ox (Cow):
columns = ['Ox']

VGG19 = 0.18485820293426514
EfficientNetB0 = 0.7246862649917603
MobileNet = 0.4041154384613037
DenseNet121 = 0.2750856578350067
ResNet50 = 0.703969419002533

data = [VGG19, EfficientNetB0, MobileNet, DenseNet121, ResNet50]

df = pd.DataFrame(data, index, columns)
df.plot.bar()
# Out:
# <Axes: >

# %%
# Crab: there are 3 (!!!) different crab labels in each model, it doesn't make any sense unless one is a biologist, so I could not calculate this one
"""
VGG19: rock_crab: 0.6381233930587769
	Dungeness_crab: 0.15698717534542084
	fiddler_crab: 0.13171032071113586
EfficientNetB0: rock_crab: 0.44452130794525146
	Dungeness_crab: 0.1867920458316803
	fiddler_crab: 0.10615978389978409
MobileNet: Dungeness_crab: 0.7618825435638428
	fiddler_crab: 0.11408849060535431
	rock_crab: 0.0867924615740776
DenseNet121: rock_crab: 0.3832370936870575
	Dungeness_crab: 0.22268061339855194
	fiddler_crab: 0.15727373957633972
ResNet50: fiddler_crab: 0.43004563450813293
	rock_crab: 0.2678390443325043
	Dungeness_crab: 0.15215305984020233
"""

# %%
# Dinosaur: there obviously (and surprisingly) no such category in this model because no model had guessed it

# %%
# Electric guitar:
columns = ['Electric guitar']

VGG19 = 0.492048442363739
EfficientNetB0 = 0.9224171042442322
MobileNet = 0.9695601463317871
DenseNet121 = 0.3288159966468811
ResNet50 = 0.4421413540840149

data = [VGG19, EfficientNetB0, MobileNet, DenseNet121, ResNet50]

df = pd.DataFrame(data, index, columns)
df.plot.bar()
# Out:
# <Axes: >

# %%
# Steam locomotive:
columns = ['Steam locomotive']

VGG19 = 0.9953247308731079
EfficientNetB0 = 0.8953731060028076
MobileNet = 0.9965139031410217
DenseNet121 = 0.9948417544364929
ResNet50 = 0.998784601688385

data = [VGG19, EfficientNetB0, MobileNet, DenseNet121, ResNet50]

df = pd.DataFrame(data, index, columns)
df.plot.bar()
# Out:
# <Axes: >

# %%
# Volcano:
columns = ['Volcano']

VGG19 = 0.9988511800765991
EfficientNetB0 = 0.8778279423713684
MobileNet = 0.9969499707221985
DenseNet121 = 0.99846351146698
ResNet50 = 0.9999794960021973

data = [VGG19, EfficientNetB0, MobileNet, DenseNet121, ResNet50]

df = pd.DataFrame(data, index, columns)
df.plot.bar()
# Out:
# <Axes: >

# %%
# Airship:
columns = ['Airship']

VGG19 = 0.8784939646720886
EfficientNetB0 = 0.8733450174331665
MobileNet = 0.9945300221443176
DenseNet121 = 0.9571380615234375
ResNet50 = 0.9958422780036926

data = [VGG19, EfficientNetB0, MobileNet, DenseNet121, ResNet50]

df = pd.DataFrame(data, index, columns)
df.plot.bar()
# Out:
# <Axes: >

# %%
# Average accuracy for 7 pictures pro model (without not existing categories):
columns = ['Average accuracy']

VGG19 = (0.7563691139221191 + 0.820897102355957 + 0.18485820293426514
         + 0.492048442363739 + 0.9953247308731079 + 0.9988511800765991
         + 0.8784939646720886) / 7
EfficientNetB0 = (0.3092358708381653 + 0.9093706607818604 + 0.7246862649917603
                  + 0.9224171042442322 + 0.8953731060028076 + 0.8778279423713684
                  + 0.8733450174331665) / 7
MobileNet = (0.5665768980979919 + 0.9754392504692078 + 0.4041154384613037
             + 0.9695601463317871 + 0.9965139031410217 + 0.9969499707221985
             + 0.9945300221443176) / 7
DenseNet121 = (0.5370401740074158 + 0.9499104619026184 + 0.2750856578350067
               + 0.3288159966468811 + 0.9948417544364929 + 0.99846351146698
               + 0.9571380615234375) / 7
ResNet50 = (0.021923772990703583 + 0.9764938950538635 + 0.703969419002533
            + 0.4421413540840149 + 0.998784601688385 + 0.9999794960021973
            + 0.9958422780036926) / 7

data = [VGG19, EfficientNetB0, MobileNet, DenseNet121, ResNet50]

df = pd.DataFrame(data, index, columns)
df.plot.bar()
# Out:
# <Axes: >
