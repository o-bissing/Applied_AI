# %%
import sys
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

csvFile = pd.read_csv('Dataset1.csv')

colNames = list(csvFile.columns)

print(colNames)
# x = csvFile[]
# Out:
# ['X0', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'Y']

# %%
Values = csvFile.values
print(Values)
# Out:
# [[-0.46693797 -1.84946618 -4.24943802 ...  1.43521841 -1.18869421
#    3.        ]
#  [-3.35179788  1.56688047 -3.38686886 ... -0.30091196  4.45647713
#    4.        ]
#  [ 1.7567191  -0.83364644  4.68768013 ...  0.168553   -5.57597555
#    1.        ]
#  ...
#  [-2.04631642  1.29190852  4.38949056 ... -4.2272903   2.68932343
#    1.        ]
#  [ 1.03570031 -0.80639549 -0.57543878 ...  0.67188163 -1.81360352
#    2.        ]
#  [ 0.77790087 -2.73398243 -3.38538958 ...  0.01482084 -2.8838918
#    0.        ]]

# %%
csvFile.head()
# Out:
#          X0        X1        X2        X3        X4        X5        X6  \
# 0 -0.466938 -1.849466 -4.249438 -0.998786 -0.757306  0.829388  1.107287
# 1 -3.351798  1.566880 -3.386869  1.357169  0.034634  0.313232  0.097467
# 2  1.756719 -0.833646  4.687680 -0.082129 -1.197701 -0.376825  0.438365
# 3 -0.120330 -1.509824 -0.460451 -0.017312 -1.809610  0.504587  0.022132
# 4  0.348181  1.586445  0.406611  0.472626  0.504803  1.444738  0.030170
#
#          X7        X8        X9       X10       X11  Y
# 0  3.146103 -1.981812  3.191490  1.435218 -1.188694  3
# 1 -0.571613 -0.181867  2.350546 -0.300912  4.456477  4
# 2 -1.004378 -2.491337 -2.282156  0.168553 -5.575976  1
# 3 -0.791507 -2.664230  0.242758  1.674560 -4.862818  2
# 4  1.744727 -2.160470  1.531058  2.973578 -2.417373  2

# %%
X0 = csvFile['X0']
print(min(X0))
print(max(X0))
print(np.mean(X0))
print(np.std(X0))
# Out:
# -5.818419105
# 6.068579224
# -0.47610235790916666
# 1.7356243297931189

# %%
plt.plot(X0)

# %%
plt.hist(X0,10)
# Out:
# (array([ 10.,  36., 126., 290., 314., 252., 111.,  40.,  20.,   1.]),
#  array([-5.81841911, -4.62971927, -3.44101944, -2.25231961, -1.06361977,
#          0.12508006,  1.31377989,  2.50247973,  3.69117956,  4.87987939,
#          6.06857922]),
#  <BarContainer object of 10 artists>)

# %%
range_value = csvFile.max()[0] - csvFile.min()[0]
range_value
# Out:
# 11.886998329

# %%
len(csvFile.axes[1])
# Out:
# 13

# %%
csvFile.shape[1]
# Out:
# 13

# %%
# print ranges
for i in range(len(csvFile.axes[1])):
    print(csvFile.max()[i] - csvFile.min()[i])
# Out:
# 11.886998329
# 12.250970867
# 22.542986551
# 11.889368476000001
# 6.359273649
# 6.777884317
# 6.291014816000001
# 14.651946348
# 15.443324396
# 11.684328259
# 12.401678349
# 24.030152440000002
# 5.0

# %%
# print mean
for i in range(len(csvFile.axes[1])):
    print(csvFile.sum()[i] / len(csvFile.axes[1]))
# Out:
# -43.947909960846154
# -21.058132098461538
# -80.039488971
# 17.133081750846156
# -0.4137847274615378
# -2.600069872076923
# 3.0479519125384615
# -22.701799504000004
# -7.914750300615385
# 19.647886805615386
# 19.154904965923077
# -4.64627771892308
# 230.15384615384616

# %%
# print standard deviation (to implement the formula takes too much time, so I used the built-in function)
csvFile.std()
# Out:
# X0     1.736348
# X1     1.757927
# X2     3.179037
# X3     1.792024
# X4     1.026440
# X5     0.998632
# X6     0.969715
# X7     1.810910
# X8     1.901909
# X9     1.751929
# X10    1.828685
# X11    3.255101
# Y      1.709012
# dtype: float64
